# %% [markdown]
# ## syllabus day 6/22/26

# %% [markdown]
# hi my name is garrett, this is day one. group members: zach, garrett, and isabella

# %%
import numpy

# %%
numpy.mean([1,2,3,4,5,6])
# Out:
# 3.5

# %%
(10 + 12)**6
# Out:
# 113379904
